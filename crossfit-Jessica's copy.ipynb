# %%
import pandas as pd

# %%
athletes = pd.read_csv("bgadoci-crossfit-data/athletes.csv")
athletes
# Out:
# c:\users\hambl\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (27) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         athlete_id             name               region  \
# 0           2554.0        Pj Ablang           South West
# 1           3517.0    Derek Abdella                  NaN
# 2           4691.0              NaN                  NaN
# 3           5164.0      Abo Brandon  Southern California
# 4           5286.0      Bryce Abbey                  NaN
# ...            ...              ...                  ...
# 423001    574489.0       Odo Renata        Latin America
# 423002    585696.0    Lozzie Trevor            Australia
# 423003    608828.0    Marisol Smith           North West
# 423004    628881.0  Pedrini Morgane               Europe
# 423005    631847.0       Eden Kenny  Northern California
#
#                            team              affiliate  gender   age  height  \
# 0                   Double Edge   Double Edge CrossFit    Male  24.0    70.0
# 1                           NaN                    NaN    Male  42.0    70.0
# 2                           NaN                    NaN     NaN   NaN     NaN
# 3                  LAX CrossFit           LAX CrossFit    Male  40.0    67.0
# 4                           NaN                    NaN    Male  32.0    65.0
# ...                         ...                    ...     ...   ...     ...
# 423001        Team Guarujá Inox       CrossFit Guaruja  Female  36.0     NaN
# 423002  FBP CrossFit Games Team           FBP CrossFit  Female  27.0     NaN
# 423003      CrossFit Oak Harbor    CrossFit Oak Harbor  Female  44.0     NaN
# 423004                      NaN            CrossFit 67  Female  20.0    64.0
# 423005                      NaN  Contra Costa CrossFit  Female  26.0     NaN
#
#         weight   fran  ...  deadlift  backsq  pullups  \
# 0        166.0    NaN  ...     400.0   305.0      NaN
# 1        190.0    NaN  ...       NaN     NaN      NaN
# 2          NaN    NaN  ...       NaN     NaN      NaN
# 3          NaN  211.0  ...     375.0   325.0     25.0
# 4        149.0  206.0  ...       NaN   325.0     50.0
# ...        ...    ...  ...       ...     ...      ...
# 423001     NaN    NaN  ...       NaN     NaN      NaN
# 423002     NaN    NaN  ...       NaN     NaN      NaN
# 423003     NaN    NaN  ...       NaN     NaN      NaN
# 423004    61.0    NaN  ...      80.0   143.0      NaN
# 423005     NaN    NaN  ...       NaN     NaN      NaN
#
#                                                       eat  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                    I eat 1-3 full cheat meals per week|
# 4       I eat quality foods but don't measure the amount|
# ...                                                   ...
# 423001                                                NaN
# 423002                                                NaN
# 423003                                                NaN
# 423004  I eat quality foods but don't measure the amount|
# 423005                                                NaN
#
#                                                     train  \
# 0       I workout mostly at a CrossFit Affiliate|I hav...
# 1       I have a coach who determines my programming|I...
# 2                                                     NaN
# 3       I workout mostly at a CrossFit Affiliate|I hav...
# 4       I workout mostly at a CrossFit Affiliate|I inc...
# ...                                                   ...
# 423001                                                NaN
# 423002                                                NaN
# 423003                                                NaN
# 423004          I workout mostly at a CrossFit Affiliate|
# 423005                                                NaN
#
#                                                background  \
# 0       I played youth or high school level sports|I r...
# 1             I played youth or high school level sports|
# 2                                                     NaN
# 3             I played youth or high school level sports|
# 4                                I played college sports|
# ...                                                   ...
# 423001                                                NaN
# 423002                                                NaN
# 423003                                                NaN
# 423004                                                NaN
# 423005                                                NaN
#
#                                                experience  \
# 0       I began CrossFit with a coach (e.g. at an affi...
# 1       I began CrossFit with a coach (e.g. at an affi...
# 2                                                     NaN
# 3       I began CrossFit by trying it alone (without a...
# 4       I began CrossFit by trying it alone (without a...
# ...                                                   ...
# 423001                                                NaN
# 423002                                                NaN
# 423003                                                NaN
# 423004  I began CrossFit with a coach (e.g. at an affi...
# 423005                                                NaN
#
#                                                  schedule       howlong  \
# 0              I do multiple workouts in a day 2x a week|     4+ years|
# 1              I do multiple workouts in a day 2x a week|     4+ years|
# 2                                                     NaN           NaN
# 3                      I usually only do 1 workout a day|     4+ years|
# 4       I usually only do 1 workout a day|I strictly s...    1-2 years|
# ...                                                   ...           ...
# 423001                                                NaN           NaN
# 423002                                                NaN           NaN
# 423003                                                NaN           NaN
# 423004  I usually only do 1 workout a day|I strictly s...  6-12 months|
# 423005                                                NaN           NaN
#
#          retrieved_datetime
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 423001  2015-03-25 09:55:05
# 423002  2015-03-25 09:55:06
# 423003  2015-03-25 09:55:07
# 423004  2015-03-25 09:55:07
# 423005  2015-03-25 09:55:08
#
# [423006 rows x 28 columns]

# %% [markdown]
# ## Braden's Preprocessing Section - Join Data and Filter Columns

# %%
# First need to read in the leader dataset
leader = pd.read_csv("bgadoci-crossfit-data/leaderboard.15.csv")

# %%
# Join on athlete ID
df = pd.merge(athletes, leader, on='athlete_id', how='inner')
# Make sure it looks okay
df.head()
# Out:
#    athlete_id       name      region         team             affiliate  \
# 0      2554.0  Pj Ablang  South West  Double Edge  Double Edge CrossFit
# 1      2554.0  Pj Ablang  South West  Double Edge  Double Edge CrossFit
# 2      2554.0  Pj Ablang  South West  Double Edge  Double Edge CrossFit
# 3      2554.0  Pj Ablang  South West  Double Edge  Double Edge CrossFit
# 4      2554.0  Pj Ablang  South West  Double Edge  Double Edge CrossFit
#
#   gender   age  height  weight  fran  ...  \
# 0   Male  24.0    70.0   166.0   NaN  ...
# 1   Male  24.0    70.0   166.0   NaN  ...
# 2   Male  24.0    70.0   166.0   NaN  ...
# 3   Male  24.0    70.0   166.0   NaN  ...
# 4   Male  24.0    70.0   166.0   NaN  ...
#
#                                      schedule    howlong  \
# 0  I do multiple workouts in a day 2x a week|  4+ years|
# 1  I do multiple workouts in a day 2x a week|  4+ years|
# 2  I do multiple workouts in a day 2x a week|  4+ years|
# 3  I do multiple workouts in a day 2x a week|  4+ years|
# 4  I do multiple workouts in a day 2x a week|  4+ years|
#
#    retrieved_datetime_x  year  division  stage     rank  score  \
# 0                   NaN    15         1    5.0  44119.0  771.0
# 1                   NaN    15         1    1.0  43966.0  130.0
# 2                   NaN    15         1    1.1  32461.0  225.0
# 3                   NaN    15         1    2.0  58455.0   78.0
# 4                   NaN    15         1    3.0  30179.0  314.0
#
#    retrieved_datetime_y  scaled
# 0   2015-03-31 21:47:26       0
# 1   2015-03-31 23:02:54       0
# 2   2015-03-31 23:30:57       0
# 3   2015-03-31 23:53:31       0
# 4   2015-04-01 00:27:51       0
#
# [5 rows x 35 columns]

# %%
# Drop all of our na's and check for unique values in each column
testing = df.dropna()
testing.nunique()
# Out:
# athlete_id               679
# name                     679
# region                    17
# team                     574
# affiliate                567
# gender                     2
# age                       38
# height                    23
# weight                   120
# fran                     313
# helen                    335
# grace                    270
# filthy50                 503
# fgonebad                 247
# run400                    95
# run5k                    381
# candj                    120
# snatch                   113
# deadlift                 141
# backsq                   133
# pullups                   80
# eat                       23
# train                     45
# background                18
# experience                43
# schedule                  51
# howlong                   12
# retrieved_datetime_x     675
# year                       1
# division                   2
# stage                      6
# rank                    2427
# score                    775
# retrieved_datetime_y    2211
# scaled                     2
# dtype: int64

# %% [markdown]
# NOTE: We noticed in our EDA that several variables had absurd responses: 800,000 pullups, 5,000 lb. back squat etc... So we used our best judgement to determine where the cutoff for a reasonable score on each continuous variable might be.

# %%
# How many rows we have before
print(len(testing))
# Out:
# 3802

# %%
# Filtered Dataframes
testing = testing[testing['fran'] < 1250]
testing = testing[testing['helen'] < 2000]
testing = testing[testing['grace'] < 1000]
testing = testing[testing['filthy50'] < 4000]
testing = testing[testing['fgonebad'] < 625]
testing = testing[testing['run400'] < 200]
testing = testing[testing['run5k'] < 3000]
testing = testing[testing['candj'] < 500]
testing = testing[testing['snatch'] < 350]
testing = testing[testing['deadlift'] < 750]
testing = testing[testing['backsq'] < 750]
testing = testing[testing['pullups'] < 74]

# %%
# Number of rows now
print(len(testing))
# Out:
# 3625

# %% [markdown]
# 3802
# 3625

# %%
# Histogram to illustrate the distribution looks okay 
testing.fran.hist(bins = 20)
# Out:
# <AxesSubplot:>

# %%
#athletes.eat.unique()

# %% [markdown]
# Possible values for eat:
# * I eat quality foods but don't measure the amount
# * I eat strict Paleo
# * I eat 1-3 full cheat meals per week
# * I eat whatever is convenient
# * I weigh and measure my food

# %%
#athletes.train.unique()

# %% [markdown]
# Possible values for train:
# * I workout mostly at a CrossFit Affiliate
# * I have a coach who determines my programming
# * I record my workouts
# * I incorporate CrossFit.com workouts
# * I write my own programming
# * I workout mostly at home, work, or a traditional gym

# %%
import numpy as np
athletes = testing

# %%
# calculate dummies for train column
athletes = athletes.dropna()
a = athletes["train"].str.split('|').explode().to_frame()
cols = a["train"].drop_duplicates(keep='first').tolist()

athletes = pd.concat([athletes, pd.crosstab(a.index, a["train"])[cols]], axis=1)

athletes.drop('train', axis=1, inplace=True)    
athletes.drop('', axis=1, inplace=True)
athletes
# Out:
#          athlete_id            name      region                 team  \
# 82091      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82092      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82093      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82094      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82095      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# ...             ...             ...         ...                  ...
# 1384129     19844.0   Valerie Foley  South West  CrossFit Initiative
# 1384130     19844.0   Valerie Foley  South West  CrossFit Initiative
# 1384131     19844.0   Valerie Foley  South West  CrossFit Initiative
# 1384132     19844.0   Valerie Foley  South West  CrossFit Initiative
# 1384133     19844.0   Valerie Foley  South West  CrossFit Initiative
#
#                    affiliate  gender   age  height  weight   fran  ...  score  \
# 82091    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...  498.0
# 82092    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...  170.0
# 82093    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...  240.0
# 82094    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...  244.0
# 82095    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...  340.0
# ...                      ...     ...   ...     ...     ...    ...  ...    ...
# 1384129  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...  131.0
# 1384130  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...  115.0
# 1384131  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...  135.0
# 1384132  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...  533.0
# 1384133  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...   77.0
#
#          retrieved_datetime_y  scaled  \
# 82091     2015-03-31 21:45:10       0
# 82092     2015-03-31 22:59:41       0
# 82093     2015-03-31 23:28:06       0
# 82094     2015-03-31 23:52:32       0
# 82095     2015-04-01 00:17:05       0
# ...                       ...     ...
# 1384129   2015-03-31 23:23:15       1
# 1384130   2015-03-31 23:48:30       1
# 1384131   2015-04-01 00:11:44       1
# 1384132   2015-04-01 00:40:56       1
# 1384133   2015-04-01 01:06:17       1
#
#          I workout mostly at a CrossFit Affiliate  \
# 82091                                           1
# 82092                                           1
# 82093                                           1
# 82094                                           1
# 82095                                           1
# ...                                           ...
# 1384129                                         1
# 1384130                                         1
# 1384131                                         1
# 1384132                                         1
# 1384133                                         1
#
#          I workout mostly at home, work, or a traditional gym  \
# 82091                                                    1
# 82092                                                    1
# 82093                                                    1
# 82094                                                    1
# 82095                                                    1
# ...                                                    ...
# 1384129                                                  0
# 1384130                                                  0
# 1384131                                                  0
# 1384132                                                  0
# 1384133                                                  0
#
#          I have a coach who determines my programming  \
# 82091                                               1
# 82092                                               1
# 82093                                               1
# 82094                                               1
# 82095                                               1
# ...                                               ...
# 1384129                                             0
# 1384130                                             0
# 1384131                                             0
# 1384132                                             0
# 1384133                                             0
#
#          I incorporate CrossFit.com workouts  I write my own programming  \
# 82091                                      1                           1
# 82092                                      1                           1
# 82093                                      1                           1
# 82094                                      1                           1
# 82095                                      1                           1
# ...                                      ...                         ...
# 1384129                                    0                           0
# 1384130                                    0                           0
# 1384131                                    0                           0
# 1384132                                    0                           0
# 1384133                                    0                           0
#
#          I record my workouts  Decline to answer
# 82091                       1                  0
# 82092                       1                  0
# 82093                       1                  0
# 82094                       1                  0
# 82095                       1                  0
# ...                       ...                ...
# 1384129                     1                  0
# 1384130                     1                  0
# 1384131                     1                  0
# 1384132                     1                  0
# 1384133                     1                  0
#
# [3625 rows x 41 columns]

# %%
# calculate dummies for background column
a = athletes["background"].str.split('|').explode().to_frame()
cols = a["background"].drop_duplicates(keep='first').tolist()

athletes = pd.concat([athletes, pd.crosstab(a.index, a["background"])[cols]], axis=1)

athletes.drop('background', axis=1, inplace=True)    
athletes.drop('', axis=1, inplace=True)
athletes
# Out:
#          athlete_id            name      region                 team  \
# 82091      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82092      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82093      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82094      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82095      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# ...             ...             ...         ...                  ...
# 1384129     19844.0   Valerie Foley  South West  CrossFit Initiative
# 1384130     19844.0   Valerie Foley  South West  CrossFit Initiative
# 1384131     19844.0   Valerie Foley  South West  CrossFit Initiative
# 1384132     19844.0   Valerie Foley  South West  CrossFit Initiative
# 1384133     19844.0   Valerie Foley  South West  CrossFit Initiative
#
#                    affiliate  gender   age  height  weight   fran  ...  \
# 82091    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...
# 82092    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...
# 82093    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...
# 82094    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...
# 82095    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...
# ...                      ...     ...   ...     ...     ...    ...  ...
# 1384129  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...
# 1384130  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...
# 1384131  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...
# 1384132  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...
# 1384133  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...
#
#          I incorporate CrossFit.com workouts  I write my own programming  \
# 82091                                      1                           1
# 82092                                      1                           1
# 82093                                      1                           1
# 82094                                      1                           1
# 82095                                      1                           1
# ...                                      ...                         ...
# 1384129                                    0                           0
# 1384130                                    0                           0
# 1384131                                    0                           0
# 1384132                                    0                           0
# 1384133                                    0                           0
#
#          I record my workouts  Decline to answer  \
# 82091                       1                  0
# 82092                       1                  0
# 82093                       1                  0
# 82094                       1                  0
# 82095                       1                  0
# ...                       ...                ...
# 1384129                     1                  0
# 1384130                     1                  0
# 1384131                     1                  0
# 1384132                     1                  0
# 1384133                     1                  0
#
#          I played youth or high school level sports  \
# 82091                                             1
# 82092                                             1
# 82093                                             1
# 82094                                             1
# 82095                                             1
# ...                                             ...
# 1384129                                           0
# 1384130                                           0
# 1384131                                           0
# 1384132                                           0
# 1384133                                           0
#
#          I regularly play recreational sports  I played college sports  \
# 82091                                       1                        0
# 82092                                       1                        0
# 82093                                       1                        0
# 82094                                       1                        0
# 82095                                       1                        0
# ...                                       ...                      ...
# 1384129                                     1                        0
# 1384130                                     1                        0
# 1384131                                     1                        0
# 1384132                                     1                        0
# 1384133                                     1                        0
#
#          I played professional sports  \
# 82091                               0
# 82092                               0
# 82093                               0
# 82094                               0
# 82095                               0
# ...                               ...
# 1384129                             0
# 1384130                             0
# 1384131                             0
# 1384132                             0
# 1384133                             0
#
#          I have no athletic background besides CrossFit  Decline to answer
# 82091                                                 0                  0
# 82092                                                 0                  0
# 82093                                                 0                  0
# 82094                                                 0                  0
# 82095                                                 0                  0
# ...                                                 ...                ...
# 1384129                                               1                  0
# 1384130                                               1                  0
# 1384131                                               1                  0
# 1384132                                               1                  0
# 1384133                                               1                  0
#
# [3625 rows x 46 columns]

# %%
# calculate dummies for experience column
a = athletes["experience"].str.split('|').explode().to_frame()
cols = a["experience"].drop_duplicates(keep='first').tolist()

athletes = pd.concat([athletes, pd.crosstab(a.index, a["experience"])[cols]], axis=1)

athletes.drop('experience', axis=1, inplace=True)    
athletes.drop('', axis=1, inplace=True)
athletes
# Out:
#          athlete_id            name      region                 team  \
# 82091      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82092      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82093      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82094      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82095      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# ...             ...             ...         ...                  ...
# 1384129     19844.0   Valerie Foley  South West  CrossFit Initiative
# 1384130     19844.0   Valerie Foley  South West  CrossFit Initiative
# 1384131     19844.0   Valerie Foley  South West  CrossFit Initiative
# 1384132     19844.0   Valerie Foley  South West  CrossFit Initiative
# 1384133     19844.0   Valerie Foley  South West  CrossFit Initiative
#
#                    affiliate  gender   age  height  weight   fran  ...  \
# 82091    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...
# 82092    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...
# 82093    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...
# 82094    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...
# 82095    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...
# ...                      ...     ...   ...     ...     ...    ...  ...
# 1384129  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...
# 1384130  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...
# 1384131  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...
# 1384132  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...
# 1384133  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...
#
#          I played professional sports  \
# 82091                               0
# 82092                               0
# 82093                               0
# 82094                               0
# 82095                               0
# ...                               ...
# 1384129                             0
# 1384130                             0
# 1384131                             0
# 1384132                             0
# 1384133                             0
#
#          I have no athletic background besides CrossFit  Decline to answer  \
# 82091                                                 0                  0
# 82092                                                 0                  0
# 82093                                                 0                  0
# 82094                                                 0                  0
# 82095                                                 0                  0
# ...                                                 ...                ...
# 1384129                                               1                  0
# 1384130                                               1                  0
# 1384131                                               1                  0
# 1384132                                               1                  0
# 1384133                                               1                  0
#
#          I began CrossFit by trying it alone (without a coach)  \
# 82091                                                    1
# 82092                                                    1
# 82093                                                    1
# 82094                                                    1
# 82095                                                    1
# ...                                                    ...
# 1384129                                                  0
# 1384130                                                  0
# 1384131                                                  0
# 1384132                                                  0
# 1384133                                                  0
#
#          I have completed the CrossFit Level 1 certificate course  \
# 82091                                                    1
# 82092                                                    1
# 82093                                                    1
# 82094                                                    1
# 82095                                                    1
# ...                                                    ...
# 1384129                                                  0
# 1384130                                                  0
# 1384131                                                  0
# 1384132                                                  0
# 1384133                                                  0
#
#          I train other people  I have attended one or more specialty courses  \
# 82091                       1                                              0
# 82092                       1                                              0
# 82093                       1                                              0
# 82094                       1                                              0
# 82095                       1                                              0
# ...                       ...                                            ...
# 1384129                     0                                              0
# 1384130                     0                                              0
# 1384131                     0                                              0
# 1384132                     0                                              0
# 1384133                     0                                              0
#
#          I have had a life changing experience due to CrossFit  \
# 82091                                                    0
# 82092                                                    0
# 82093                                                    0
# 82094                                                    0
# 82095                                                    0
# ...                                                    ...
# 1384129                                                  0
# 1384130                                                  0
# 1384131                                                  0
# 1384132                                                  0
# 1384133                                                  0
#
#          I began CrossFit with a coach (e.g. at an affiliate)  \
# 82091                                                    0
# 82092                                                    0
# 82093                                                    0
# 82094                                                    0
# 82095                                                    0
# ...                                                    ...
# 1384129                                                  1
# 1384130                                                  1
# 1384131                                                  1
# 1384132                                                  1
# 1384133                                                  1
#
#          Decline to answer
# 82091                    0
# 82092                    0
# 82093                    0
# 82094                    0
# 82095                    0
# ...                    ...
# 1384129                  0
# 1384130                  0
# 1384131                  0
# 1384132                  0
# 1384133                  0
#
# [3625 rows x 52 columns]

# %%
# calculate dummies for schedule column
a = athletes["schedule"].str.split('|').explode().to_frame()
cols = a["schedule"].drop_duplicates(keep='first').tolist()

athletes = pd.concat([athletes, pd.crosstab(a.index, a["schedule"])[cols]], axis=1)

athletes.drop('schedule', axis=1, inplace=True)    
athletes.drop('', axis=1, inplace=True)
athletes
# Out:
#          athlete_id            name      region                 team  \
# 82091      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82092      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82093      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82094      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82095      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# ...             ...             ...         ...                  ...
# 1384129     19844.0   Valerie Foley  South West  CrossFit Initiative
# 1384130     19844.0   Valerie Foley  South West  CrossFit Initiative
# 1384131     19844.0   Valerie Foley  South West  CrossFit Initiative
# 1384132     19844.0   Valerie Foley  South West  CrossFit Initiative
# 1384133     19844.0   Valerie Foley  South West  CrossFit Initiative
#
#                    affiliate  gender   age  height  weight   fran  ...  \
# 82091    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...
# 82092    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...
# 82093    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...
# 82094    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...
# 82095    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...
# ...                      ...     ...   ...     ...     ...    ...  ...
# 1384129  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...
# 1384130  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...
# 1384131  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...
# 1384132  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...
# 1384133  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...
#
#          I began CrossFit with a coach (e.g. at an affiliate)  \
# 82091                                                    0
# 82092                                                    0
# 82093                                                    0
# 82094                                                    0
# 82095                                                    0
# ...                                                    ...
# 1384129                                                  1
# 1384130                                                  1
# 1384131                                                  1
# 1384132                                                  1
# 1384133                                                  1
#
#          Decline to answer  I do multiple workouts in a day 3+ times a week  \
# 82091                    0                                                1
# 82092                    0                                                1
# 82093                    0                                                1
# 82094                    0                                                1
# 82095                    0                                                1
# ...                    ...                                              ...
# 1384129                  0                                                0
# 1384130                  0                                                0
# 1384131                  0                                                0
# 1384132                  0                                                0
# 1384133                  0                                                0
#
#          I typically rest fewer than 4 days per month  \
# 82091                                               1
# 82092                                               1
# 82093                                               1
# 82094                                               1
# 82095                                               1
# ...                                               ...
# 1384129                                             0
# 1384130                                             0
# 1384131                                             0
# 1384132                                             0
# 1384133                                             0
#
#          I typically rest 4 or more days per month  \
# 82091                                            0
# 82092                                            0
# 82093                                            0
# 82094                                            0
# 82095                                            0
# ...                                            ...
# 1384129                                          1
# 1384130                                          1
# 1384131                                          1
# 1384132                                          1
# 1384133                                          1
#
#          I usually only do 1 workout a day  \
# 82091                                    0
# 82092                                    0
# 82093                                    0
# 82094                                    0
# 82095                                    0
# ...                                    ...
# 1384129                                  1
# 1384130                                  1
# 1384131                                  1
# 1384132                                  1
# 1384133                                  1
#
#          I do multiple workouts in a day 1x a week  \
# 82091                                            0
# 82092                                            0
# 82093                                            0
# 82094                                            0
# 82095                                            0
# ...                                            ...
# 1384129                                          0
# 1384130                                          0
# 1384131                                          0
# 1384132                                          0
# 1384133                                          0
#
#          I strictly schedule my rest days  \
# 82091                                   0
# 82092                                   0
# 82093                                   0
# 82094                                   0
# 82095                                   0
# ...                                   ...
# 1384129                                 0
# 1384130                                 0
# 1384131                                 0
# 1384132                                 0
# 1384133                                 0
#
#          I do multiple workouts in a day 2x a week  Decline to answer
# 82091                                            0                  0
# 82092                                            0                  0
# 82093                                            0                  0
# 82094                                            0                  0
# 82095                                            0                  0
# ...                                            ...                ...
# 1384129                                          0                  0
# 1384130                                          0                  0
# 1384131                                          0                  0
# 1384132                                          0                  0
# 1384133                                          0                  0
#
# [3625 rows x 59 columns]

# %%
# calculate dummies for schedule column
a = athletes["eat"].str.split('|').explode().to_frame()
cols = a["eat"].drop_duplicates(keep='first').tolist()

athletes = pd.concat([athletes, pd.crosstab(a.index, a["eat"])[cols]], axis=1)

athletes.drop('eat', axis=1, inplace=True)    
athletes.drop('', axis=1, inplace=True)
athletes
# Out:
#          athlete_id            name      region                 team  \
# 82091      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82092      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82093      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82094      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82095      244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# ...             ...             ...         ...                  ...
# 1384129     19844.0   Valerie Foley  South West  CrossFit Initiative
# 1384130     19844.0   Valerie Foley  South West  CrossFit Initiative
# 1384131     19844.0   Valerie Foley  South West  CrossFit Initiative
# 1384132     19844.0   Valerie Foley  South West  CrossFit Initiative
# 1384133     19844.0   Valerie Foley  South West  CrossFit Initiative
#
#                    affiliate  gender   age  height  weight   fran  ...  \
# 82091    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...
# 82092    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...
# 82093    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...
# 82094    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...
# 82095    CrossFit Cedar City    Male  25.0    70.0   183.0  189.0  ...
# ...                      ...     ...   ...     ...     ...    ...  ...
# 1384129  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...
# 1384130  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...
# 1384131  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...
# 1384132  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...
# 1384133  CrossFit Initiative  Female  30.0    66.0   150.0  529.0  ...
#
#          I do multiple workouts in a day 1x a week  \
# 82091                                            0
# 82092                                            0
# 82093                                            0
# 82094                                            0
# 82095                                            0
# ...                                            ...
# 1384129                                          0
# 1384130                                          0
# 1384131                                          0
# 1384132                                          0
# 1384133                                          0
#
#          I strictly schedule my rest days  \
# 82091                                   0
# 82092                                   0
# 82093                                   0
# 82094                                   0
# 82095                                   0
# ...                                   ...
# 1384129                                 0
# 1384130                                 0
# 1384131                                 0
# 1384132                                 0
# 1384133                                 0
#
#          I do multiple workouts in a day 2x a week  Decline to answer  \
# 82091                                            0                  0
# 82092                                            0                  0
# 82093                                            0                  0
# 82094                                            0                  0
# 82095                                            0                  0
# ...                                            ...                ...
# 1384129                                          0                  0
# 1384130                                          0                  0
# 1384131                                          0                  0
# 1384132                                          0                  0
# 1384133                                          0                  0
#
#          I eat quality foods but don't measure the amount  \
# 82091                                                   1
# 82092                                                   1
# 82093                                                   1
# 82094                                                   1
# 82095                                                   1
# ...                                                   ...
# 1384129                                                 0
# 1384130                                                 0
# 1384131                                                 0
# 1384132                                                 0
# 1384133                                                 0
#
#          I eat 1-3 full cheat meals per week  I eat whatever is convenient  \
# 82091                                      0                             0
# 82092                                      0                             0
# 82093                                      0                             0
# 82094                                      0                             0
# 82095                                      0                             0
# ...                                      ...                           ...
# 1384129                                    0                             1
# 1384130                                    0                             1
# 1384131                                    0                             1
# 1384132                                    0                             1
# 1384133                                    0                             1
#
#          I weigh and measure my food  I eat strict Paleo  Decline to answer
# 82091                              0                   0                  0
# 82092                              0                   0                  0
# 82093                              0                   0                  0
# 82094                              0                   0                  0
# 82095                              0                   0                  0
# ...                              ...                 ...                ...
# 1384129                            0                   1                  0
# 1384130                            0                   1                  0
# 1384131                            0                   1                  0
# 1384132                            0                   1                  0
# 1384133                            0                   1                  0
#
# [3625 rows x 64 columns]

# %%
athletes.head()
# Out:
#        athlete_id            name      region                 team  \
# 82091    244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82092    244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82093    244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82094    244917.0  Andrew Hanscom  South West  CrossFit Cedar City
# 82095    244917.0  Andrew Hanscom  South West  CrossFit Cedar City
#
#                  affiliate gender   age  height  weight   fran  ...  \
# 82091  CrossFit Cedar City   Male  25.0    70.0   183.0  189.0  ...
# 82092  CrossFit Cedar City   Male  25.0    70.0   183.0  189.0  ...
# 82093  CrossFit Cedar City   Male  25.0    70.0   183.0  189.0  ...
# 82094  CrossFit Cedar City   Male  25.0    70.0   183.0  189.0  ...
# 82095  CrossFit Cedar City   Male  25.0    70.0   183.0  189.0  ...
#
#        I do multiple workouts in a day 1x a week  \
# 82091                                          0
# 82092                                          0
# 82093                                          0
# 82094                                          0
# 82095                                          0
#
#        I strictly schedule my rest days  \
# 82091                                 0
# 82092                                 0
# 82093                                 0
# 82094                                 0
# 82095                                 0
#
#        I do multiple workouts in a day 2x a week  Decline to answer  \
# 82091                                          0                  0
# 82092                                          0                  0
# 82093                                          0                  0
# 82094                                          0                  0
# 82095                                          0                  0
#
#        I eat quality foods but don't measure the amount  \
# 82091                                                 1
# 82092                                                 1
# 82093                                                 1
# 82094                                                 1
# 82095                                                 1
#
#        I eat 1-3 full cheat meals per week  I eat whatever is convenient  \
# 82091                                    0                             0
# 82092                                    0                             0
# 82093                                    0                             0
# 82094                                    0                             0
# 82095                                    0                             0
#
#        I weigh and measure my food  I eat strict Paleo  Decline to answer
# 82091                            0                   0                  0
# 82092                            0                   0                  0
# 82093                            0                   0                  0
# 82094                            0                   0                  0
# 82095                            0                   0                  0
#
# [5 rows x 64 columns]

# %%
#athletes.background.unique()

# %% [markdown]
# Possible values for background:
# * I played youth or high school level sports
# * I regularly play recreational sports
# * I played college sports
# * I have no athletic background besides CrossFit
# * I played professional sports

# %%
#athletes.experience.unique()

# %% [markdown]
# Possible values for experience:
# * I began CrossFit with a coach (e.g. at an affiliate)
# * I have attended one or more specialty courses
# * I have had a life changing experience due to CrossFit
# * I began CrossFit by trying it alone (without a coach)
# * I have completed the CrossFit Level 1 certificate course
# * I train other people

# %%
#athletes.schedule.unique()

# %% [markdown]
# Possible values for schedule:
# * I do multiple workouts in a day 2x a week
# * I usually only do 1 workout a day
# * I strictly schedule my rest days
# * I typically rest 4 or more days per month
# * I do multiple workouts in a day 3+ times a week
# * I typically rest fewer than 4 days per month
# * I do multiple workouts in a day 1x a week

# %%
#athletes.howlong.unique()

# %%
athletes.age.describe()
# Out:
# count    331110.000000
# mean         32.516750
# std           7.730671
# min          13.000000
# 25%          27.000000
# 50%          31.000000
# 75%          37.000000
# max         125.000000
# Name: age, dtype: float64

# %%
athletes.height.describe()
# Out:
# count    1.598690e+05
# mean     1.206217e+02
# std      2.097995e+04
# min      0.000000e+00
# 25%      6.600000e+01
# 50%      6.900000e+01
# 75%      7.200000e+01
# max      8.388607e+06
# Name: height, dtype: float64

# %%
athletes.weight.describe()
# Out:
# count    229890.000000
# mean        170.896137
# std          58.379799
# min           1.000000
# 25%         145.000000
# 50%         170.000000
# 75%         192.000000
# max       20175.000000
# Name: weight, dtype: float64

# %%
 athletes.fran.describe()
# Out:
# count    5.542600e+04
# mean     9.886691e+02
# std      7.200430e+04
# min      1.000000e+00
# 25%      2.150000e+02
# 50%      2.900000e+02
# 75%      3.920000e+02
# max      8.388607e+06
# Name: fran, dtype: float64

# %%
 athletes.helen.describe()
# Out:
# count    3.027900e+04
# mean     1.207950e+03
# std      6.824091e+04
# min      1.000000e+00
# 25%      5.250000e+02
# 50%      5.950000e+02
# 75%      6.940000e+02
# max      8.388607e+06
# Name: helen, dtype: float64

# %%
 athletes.grace.describe()
# Out:
# count    4.074500e+04
# mean     5.766025e+02
# std      4.891145e+04
# min     -6.000000e+01
# 25%      1.490000e+02
# 50%      1.930000e+02
# 75%      2.620000e+02
# max      8.388607e+06
# Name: grace, dtype: float64

# %%
 athletes.filthy50.describe()
# Out:
# count    1.935900e+04
# mean     2.127863e+03
# std      6.055021e+04
# min      1.000000e+00
# 25%      1.308000e+03
# 50%      1.550000e+03
# 75%      1.809000e+03
# max      8.388607e+06
# Name: filthy50, dtype: float64

# %%
 athletes.fgonebad.describe()
# Out:
# count    2.973800e+04
# mean     1.472252e+03
# std      9.762688e+04
# min      0.000000e+00
# 25%      2.400000e+02
# 50%      2.940000e+02
# 75%      3.360000e+02
# max      8.388607e+06
# Name: fgonebad, dtype: float64

# %%
 athletes.run400.describe()
# Out:
# count    2.224600e+04
# mean     5.241279e+02
# std      5.628804e+04
# min      1.000000e+00
# 25%      6.200000e+01
# 50%      7.100000e+01
# 75%      8.400000e+01
# max      8.388607e+06
# Name: run400, dtype: float64

# %%
 athletes.run5k.describe()
# Out:
# count    3.609700e+04
# mean     3.411464e+03
# std      1.251980e+05
# min      1.000000e+00
# 25%      1.242000e+03
# 50%      1.380000e+03
# 75%      1.560000e+03
# max      8.388607e+06
# Name: run5k, dtype: float64

# %%
 athletes.candj.describe()
# Out:
# count    1.044350e+05
# mean     2.709107e+02
# std      2.596882e+04
# min     -4.500000e+01
# 25%      1.400000e+02
# 50%      1.950000e+02
# 75%      2.350000e+02
# max      8.388607e+06
# Name: candj, dtype: float64

# %%
 athletes.snatch.describe()
# Out:
# count    9.728000e+04
# mean     2.424957e+02
# std      2.708942e+04
# min      0.000000e+00
# 25%      1.050000e+02
# 50%      1.450000e+02
# 75%      1.850000e+02
# max      8.388607e+06
# Name: snatch, dtype: float64

# %%
 athletes.deadlift.describe()
# Out:
# count    1.153230e+05
# mean     6.970503e+02
# std      5.523235e+04
# min     -5.000000e+02
# 25%      2.550000e+02
# 50%      3.450000e+02
# 75%      4.150000e+02
# max      8.388607e+06
# Name: deadlift, dtype: float64

# %%
 athletes.backsq.describe()
# Out:
# count    1.105170e+05
# mean     5.852109e+02
# std      5.052976e+04
# min     -7.000000e+00
# 25%      2.050000e+02
# 50%      2.750000e+02
# 75%      3.350000e+02
# max      8.388607e+06
# Name: backsq, dtype: float64

# %%
 athletes.pullups.describe()
# Out:
# count    5.060800e+04
# mean     4.269613e+04
# std      9.546078e+06
# min     -6.000000e+00
# 25%      1.500000e+01
# 50%      2.700000e+01
# 75%      3.900000e+01
# max      2.147484e+09
# Name: pullups, dtype: float64

# %%
athletes[athletes.pullups > 1000]
# Out:
#         athlete_id                name               region  \
# 5855       50693.0      Matt Cavallaro            Australia
# 8051       40813.0          Ian Daniel                  NaN
# 41837     154136.0        Eric McCombs        South Central
# 76928     294596.0        Jake Overton        South Central
# 79927     112778.0   Andrew Chalabardo        Latin America
# 83976     242168.0    Miles McIlhargie           South West
# 104689    157436.0          Peter Ryan            Australia
# 105195    547375.0         Coach Robot  Southern California
# 118325     55920.0        Damon Rudish           South East
# 124868    493027.0         Derek Akers        South Central
# 169658     28883.0  Michelle Forrester            Australia
# 186474    173097.0      Vicky Rodrigue          Canada East
# 279173    104054.0          Ryan Isaac                  NaN
# 279879    292835.0         Andy Judson  Southern California
# 345465    310629.0          Lily Price            Australia
# 381255     19529.0    kenneth thompson                  NaN
#
#                                    team               affiliate  gender   age  \
# 5855    CrossFit Conditioning Narrabeen   CrossFit Conditioning    Male  35.0
# 8051                                NaN                     NaN    Male  24.0
# 41837                    Adino Warriors          CrossFit Adino    Male  27.0
# 76928                         Ex Nihilo      CrossFit Ex Nihilo    Male  27.0
# 79927        CROSSFIT SP Bsb HULKS TEAM             CrossFit SP    Male  32.0
# 83976             CrossFit Pandoras box  CrossFit Pandora's Box    Male  35.0
# 104689                CrossFit Maitland       CrossFit Maitland    Male  35.0
# 105195                     LAX CrossFit            LAX CrossFit    Male  35.0
# 118325                              NaN         CrossFit Santos    Male  26.0
# 124868                            MXTCF            MXT CrossFit    Male  25.0
# 169658                     BTS CrossFit            BTS CrossFit  Female  38.0
# 186474                   CrossFit Angus          CrossFit Angus  Female  34.0
# 279173                              NaN                     NaN    Male  34.0
# 279879               CrossFit Escondido      CrossFit Escondido    Male  27.0
# 345465                              NaN           CrossFit TRex  Female  16.0
# 381255                              NaN                     NaN    Male  34.0
#
#         height  weight      fran  ...   deadlift     backsq       pullups  \
# 5855      70.0   173.0    3348.0  ...     1000.0       25.0  1.034000e+03
# 8051      68.0   195.0      77.0  ...    10000.0     8000.0  9.999900e+04
# 41837     96.0   185.0      60.0  ...      699.0      800.0  7.000000e+03
# 76928     69.0   179.0     115.0  ...      485.0      485.0  3.000000e+03
# 79927     68.0   180.0      60.0  ...     1168.0     1268.0  3.000000e+03
# 83976     73.0   195.0       NaN  ...      375.0      305.0  1.000000e+06
# 104689    72.0   211.0    3208.0  ...     1936.0       51.0  9.972638e+06
# 105195    73.0   178.0      72.0  ...     9999.0     9999.0  9.999000e+03
# 118325    66.0   155.0       NaN  ...      475.0      385.0  2.147484e+09
# 124868     NaN  9008.0    5400.0  ...     9000.0     9000.0  9.000000e+03
# 169658    68.0   165.0  300000.0  ...  8388607.0     1984.0  5.000000e+05
# 186474    64.0   130.0     500.0  ...      235.0      180.0  1.000000e+05
# 279173    72.0   200.0    2357.0  ...       23.0        5.0  1.178900e+04
# 279879    75.0   215.0       NaN  ...  8388607.0  8388607.0  7.000000e+03
# 345465     NaN     NaN       NaN  ...        NaN        NaN  8.000000e+04
# 381255    71.0   174.0      30.0  ...     1102.0       37.0  5.432100e+04
#
#                                                       eat  \
# 5855                 I eat 1-3 full cheat meals per week|
# 8051                                                  NaN
# 41837                       I eat whatever is convenient|
# 76928   I eat quality foods but don't measure the amou...
# 79927                                                 NaN
# 83976   I eat quality foods but don't measure the amount|
# 104689                      I eat whatever is convenient|
# 105195                                                NaN
# 118325  I eat quality foods but don't measure the amou...
# 124868                                                NaN
# 169658  I eat quality foods but don't measure the amount|
# 186474                                                NaN
# 279173  I eat quality foods but don't measure the amount|
# 279879                                                NaN
# 345465                                                NaN
# 381255  I eat quality foods but don't measure the amount|
#
#                                                     train  \
# 5855    I workout mostly at a CrossFit Affiliate|I wor...
# 8051                                                  NaN
# 41837           I workout mostly at a CrossFit Affiliate|
# 76928   I workout mostly at a CrossFit Affiliate|I wri...
# 79927                                                 NaN
# 83976           I workout mostly at a CrossFit Affiliate|
# 104689          I workout mostly at a CrossFit Affiliate|
# 105195                                                NaN
# 118325          I workout mostly at a CrossFit Affiliate|
# 124868                                                NaN
# 169658      I have a coach who determines my programming|
# 186474  I workout mostly at a CrossFit Affiliate|I hav...
# 279173          I workout mostly at a CrossFit Affiliate|
# 279879                                                NaN
# 345465                                                NaN
# 381255          I workout mostly at a CrossFit Affiliate|
#
#                                                background  \
# 5855                I regularly play recreational sports|
# 8051                                                  NaN
# 41837   I played youth or high school level sports|I r...
# 76928   I played college sports|I regularly play recre...
# 79927                                                 NaN
# 83976     I have no athletic background besides CrossFit|
# 104689              I regularly play recreational sports|
# 105195                                                NaN
# 118325        I played youth or high school level sports|
# 124868                                                NaN
# 169658    I have no athletic background besides CrossFit|
# 186474                                                NaN
# 279173        I played youth or high school level sports|
# 279879                                                NaN
# 345465                                                NaN
# 381255        I played youth or high school level sports|
#
#                                                experience  \
# 5855    I began CrossFit with a coach (e.g. at an affi...
# 8051                                                  NaN
# 41837   I began CrossFit with a coach (e.g. at an affi...
# 76928   I began CrossFit by trying it alone (without a...
# 79927                                                 NaN
# 83976   I began CrossFit with a coach (e.g. at an affi...
# 104689  I began CrossFit with a coach (e.g. at an affi...
# 105195                                                NaN
# 118325  I began CrossFit with a coach (e.g. at an affi...
# 124868                                                NaN
# 169658  I began CrossFit with a coach (e.g. at an affi...
# 186474  I began CrossFit with a coach (e.g. at an affi...
# 279173  I began CrossFit by trying it alone (without a...
# 279879                                                NaN
# 345465                                                NaN
# 381255  I have completed the CrossFit Level 1 certific...
#
#                                                  schedule     howlong  \
# 5855           I typically rest 4 or more days per month|   4+ years|
# 8051                                                  NaN         NaN
# 41837          I typically rest 4 or more days per month|   4+ years|
# 76928   I do multiple workouts in a day 3+ times a wee...  1-2 years|
# 79927                                                 NaN         NaN
# 83976                  I usually only do 1 workout a day|  2-4 years|
# 104689         I typically rest 4 or more days per month|  2-4 years|
# 105195                                                NaN         NaN
# 118325  I usually only do 1 workout a day|I typically ...   4+ years|
# 124868                                                NaN         NaN
# 169658                 I usually only do 1 workout a day|  2-4 years|
# 186474  I do multiple workouts in a day 3+ times a wee...  1-2 years|
# 279173   I do multiple workouts in a day 3+ times a week|   4+ years|
# 279879                                                NaN         NaN
# 345465                                                NaN         NaN
# 381255  I usually only do 1 workout a day|I do multipl...   4+ years|
#
#          retrieved_datetime
# 5855                    NaN
# 8051                    NaN
# 41837   2015-03-02 08:31:34
# 76928   2015-03-02 22:25:51
# 79927   2015-03-02 23:09:11
# 83976   2015-03-02 23:59:15
# 104689  2015-03-03 04:23:54
# 105195  2015-03-03 04:28:29
# 118325  2015-03-03 23:02:27
# 124868  2015-03-04 00:17:30
# 169658  2015-03-04 14:16:12
# 186474  2015-03-04 17:07:35
# 279173  2015-03-05 14:40:56
# 279879  2015-03-05 14:51:19
# 345465  2015-03-06 06:24:35
# 381255  2015-03-06 11:06:35
#
# [16 rows x 28 columns]

# %%
athletes["male"] = pd.get_dummies(X.gender)["Male"]

# %%
athletes.drop('athlete_id', axis=1)
# Out:
#                    name      region                 team            affiliate  \
# 82091    Andrew Hanscom  South West  CrossFit Cedar City  CrossFit Cedar City
# 82092    Andrew Hanscom  South West  CrossFit Cedar City  CrossFit Cedar City
# 82093    Andrew Hanscom  South West  CrossFit Cedar City  CrossFit Cedar City
# 82094    Andrew Hanscom  South West  CrossFit Cedar City  CrossFit Cedar City
# 82095    Andrew Hanscom  South West  CrossFit Cedar City  CrossFit Cedar City
# ...                 ...         ...                  ...                  ...
# 1384129   Valerie Foley  South West  CrossFit Initiative  CrossFit Initiative
# 1384130   Valerie Foley  South West  CrossFit Initiative  CrossFit Initiative
# 1384131   Valerie Foley  South West  CrossFit Initiative  CrossFit Initiative
# 1384132   Valerie Foley  South West  CrossFit Initiative  CrossFit Initiative
# 1384133   Valerie Foley  South West  CrossFit Initiative  CrossFit Initiative
#
#          gender   age  height  weight   fran  helen  ...  \
# 82091      Male  25.0    70.0   183.0  189.0  441.0  ...
# 82092      Male  25.0    70.0   183.0  189.0  441.0  ...
# 82093      Male  25.0    70.0   183.0  189.0  441.0  ...
# 82094      Male  25.0    70.0   183.0  189.0  441.0  ...
# 82095      Male  25.0    70.0   183.0  189.0  441.0  ...
# ...         ...   ...     ...     ...    ...    ...  ...
# 1384129  Female  30.0    66.0   150.0  529.0  962.0  ...
# 1384130  Female  30.0    66.0   150.0  529.0  962.0  ...
# 1384131  Female  30.0    66.0   150.0  529.0  962.0  ...
# 1384132  Female  30.0    66.0   150.0  529.0  962.0  ...
# 1384133  Female  30.0    66.0   150.0  529.0  962.0  ...
#
#          I strictly schedule my rest days  \
# 82091                                   0
# 82092                                   0
# 82093                                   0
# 82094                                   0
# 82095                                   0
# ...                                   ...
# 1384129                                 0
# 1384130                                 0
# 1384131                                 0
# 1384132                                 0
# 1384133                                 0
#
#          I do multiple workouts in a day 2x a week  Decline to answer  \
# 82091                                            0                  0
# 82092                                            0                  0
# 82093                                            0                  0
# 82094                                            0                  0
# 82095                                            0                  0
# ...                                            ...                ...
# 1384129                                          0                  0
# 1384130                                          0                  0
# 1384131                                          0                  0
# 1384132                                          0                  0
# 1384133                                          0                  0
#
#          I eat quality foods but don't measure the amount  \
# 82091                                                   1
# 82092                                                   1
# 82093                                                   1
# 82094                                                   1
# 82095                                                   1
# ...                                                   ...
# 1384129                                                 0
# 1384130                                                 0
# 1384131                                                 0
# 1384132                                                 0
# 1384133                                                 0
#
#          I eat 1-3 full cheat meals per week  I eat whatever is convenient  \
# 82091                                      0                             0
# 82092                                      0                             0
# 82093                                      0                             0
# 82094                                      0                             0
# 82095                                      0                             0
# ...                                      ...                           ...
# 1384129                                    0                             1
# 1384130                                    0                             1
# 1384131                                    0                             1
# 1384132                                    0                             1
# 1384133                                    0                             1
#
#          I weigh and measure my food  I eat strict Paleo  Decline to answer  \
# 82091                              0                   0                  0
# 82092                              0                   0                  0
# 82093                              0                   0                  0
# 82094                              0                   0                  0
# 82095                              0                   0                  0
# ...                              ...                 ...                ...
# 1384129                            0                   1                  0
# 1384130                            0                   1                  0
# 1384131                            0                   1                  0
# 1384132                            0                   1                  0
# 1384133                            0                   1                  0
#
#          male
# 82091       1
# 82092       1
# 82093       1
# 82094       1
# 82095       1
# ...       ...
# 1384129     0
# 1384130     0
# 1384131     0
# 1384132     0
# 1384133     0
#
# [3625 rows x 64 columns]

# %%
X = athletes.drop(['rank', 'athlete_id', 'name', 'region', 'team', 'affiliate', 'howlong', 'retrieved_datetime_x','retrieved_datetime_y', 'gender'], axis=1)
y = athletes["rank"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .3, random_state=801)

# %% [markdown]
# Decision tree model

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.model_selection import train_test_split, cross_val_score
import seaborn as sns
from sklearn.metrics import mean_squared_error, r2_score

# %%
# split train and test
# done above

# %%
def PipeTree(max_depth=None):
    return make_pipeline(StandardScaler(),
                         DecisionTreeRegressor(max_depth=6, random_state=0))

# %%
pipe = PipeTree()
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('decisiontreeregressor',
#                  DecisionTreeRegressor(max_depth=6, random_state=0))])

# %%
pipe = PipeTree(max_depth=5)
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('decisiontreeregressor',
#                  DecisionTreeRegressor(max_depth=6, random_state=0))])

# %%
pipe = PipeTree(max_depth=3)
pipe.fit(X_train,y_train)

# %%
pipe.named_steps
# Out:
# {'standardscaler': StandardScaler(),
#  'decisiontreeregressor': DecisionTreeRegressor(max_depth=6)}

# %%
# takes a long time to run
param_grid = [{'decisiontreeregressor__max_depth': list(np.arange(1,50))},
             {'decisiontreeregressor__min_samples_leaf': list(np.arange(1,20))}] 
gs = GridSearchCV(pipe, param_grid, scoring='neg_mean_squared_error')
gs.fit(X_train, y_train)
gs.best_params_
# Out:
# {'decisiontreeregressor__max_depth': 16}

# %%
pipe = PipeTree(max_depth=16)
pipe.fit(X_train,y_train)

# %%
y_hat = pipe.predict(X_test)
mse = mean_squared_error(y_test, y_hat)
mse
# Out:
# 159448160.3371406

# %% [markdown]
# bagging

# %% [markdown]
# knn
